# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style

# %% [markdown]
# ## Importing data

# %%
train_df = pd.read_csv(r'C:\Users\rajsi\Desktop\train mobile price.csv')
test_df = pd.read_csv(r'C:\Users\rajsi\Desktop\test mobile.csv')

# %% [markdown]
# ### Exploring data

# %%
train_df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
test_df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1043     1          1.8         1  14       0           5    0.1
# 1            841     1          0.5         1   4       1          61    0.8
# 2           1807     1          2.8         0   1       0          27    0.9
# 3           1546     0          0.5         1  18       1          25    0.5
# 4           1434     0          1.4         0  11       1          49    0.5
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        193        3  16        226      1412  3476    12     7          2
# 1        191        5  12        746       857  3895     6     0          7
# 2        186        3   4       1270      1366  2396    17    10         10
# 3         96        8  20        295      1752  3893    10     0          7
# 4        108        6  18        749       810  1773    15     8          7
#
#    three_g  touch_screen  wifi
# ...

# %%
test_df.tail()
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 995           1700     1          1.9         0   0       1          54
# 996            609     0          1.8         1   0       0          13
# 997           1185     0          1.4         0   1       1           8
# 998           1533     1          0.5         1   0       0          50
# 999           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 995    0.5        170        7  17        644       913  2121    14     8
# 996    0.9        186        4   2       1152      1632  1933     8     1
# 997    0.5         80        1  12        477       825  1223     5     0
# 998    0.4        171        2  12         38       832  2509    15    11
# 999    0.1        140        6  19        457       608  2828     9     2
#
#      talk_time  three_g  touch_screen  wifi
# ...

# %%
train_df.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
test_df.shape
# Out:
# (1000, 20)

# %%
train_df.shape
# Out:
# (2000, 21)

# %%
test_df.describe()
# Out:
#        battery_power         blue  clock_speed     dual_sim           fc  \
# count    1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     1248.510000     0.516000     1.540900     0.517000     4.593000
# std       432.458227     0.499994     0.829268     0.499961     4.463325
# min       500.000000     0.000000     0.500000     0.000000     0.000000
# 25%       895.000000     0.000000     0.700000     0.000000     1.000000
# 50%      1246.500000     1.000000     1.500000     1.000000     3.000000
# 75%      1629.250000     1.000000     2.300000     1.000000     7.000000
# max      1999.000000     1.000000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep   mobile_wt      n_cores  \
# count  1000.000000  1000.000000  1000.000000  1000.00000  1000.000000
# mean      0.487000    33.652000     0.517500   139.51100     4.328000
# std       0.500081    18.128694     0.280861    34.85155     2.288155
# ...

# %%
train_df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  1000 non-null   int64
#  1   blue           1000 non-null   int64
#  2   clock_speed    1000 non-null   float64
#  3   dual_sim       1000 non-null   int64
#  4   fc             1000 non-null   int64
#  5   four_g         1000 non-null   int64
#  6   int_memory     1000 non-null   int64
#  7   m_dep          1000 non-null   float64
#  8   mobile_wt      1000 non-null   int64
#  9   n_cores        1000 non-null   int64
#  10  pc             1000 non-null   int64
#  11  px_height      1000 non-null   int64
#  12  px_width       1000 non-null   int64
#  13  ram            1000 non-null   int64
#  14  sc_h           1000 non-null   int64
#  15  sc_w           1000 non-null   int64
#  16  talk_time      1000 non-null   int64
#  17  three_g        1000 non-null   int64
# ...

# %%
test_df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# dtype: int64

# %%
test_df.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# dtype: object

# %%
train_df.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
train_df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
test_df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi'],
#       dtype='object')

# %%
train_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %%
test_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
train_df.duplicated().sum()
# Out:
# 0

# %%
test_df.duplicated().sum()
# Out:
# 0

# %%
train_df.drop_duplicates()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
#    ### Checking for outliers in the data

# %%
train_df.plot(kind='box',figsize=(20,10))
plt.show()

# %%
# Create the scatter plot
scatter_plot = train_df.plot(x='price_range', y='ram', kind='scatter', figsize=(10, 6), alpha=0.6, s=50, c='green')

# Add labels and title
scatter_plot.set_xlabel('Price Range')
scatter_plot.set_ylabel('RAM')
scatter_plot.set_title('RAM vs. Price Range')

# Optionally, you can add a trend line
import numpy as np
z = np.polyfit(train_df['price_range'], train_df['ram'], 1)
p = np.poly1d(z)
plt.plot(train_df['price_range'], p(train_df['price_range']), "r--")

# Show the plot
plt.grid(True)
plt.show()

# %%
train_df.plot(x='price_range',y='n_cores',kind='scatter')
plt.show()

# %%
# Create the scatter plot
scatter_plot = train_df.plot(x='price_range', y='n_cores', kind='scatter', figsize=(10, 6), alpha=0.6, s=50, c='blue')

# Add labels and title
scatter_plot.set_xlabel('Price Range')
scatter_plot.set_ylabel('Number of Cores')
scatter_plot.set_title('Number of Cores vs. Price Range')

# Optionally, you can add a trend line
import numpy as np
z = np.polyfit(train_df['price_range'], train_df['n_cores'], 1)
p = np.poly1d(z)
plt.plot(train_df['price_range'],p(train_df['price_range']),"r--")

# Show the plot
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Create the scatter plot
scatter_plot = train_df.plot(x='price_range', y='fc', kind='scatter', figsize=(10, 6), alpha=0.6, s=50, c='blue')

# Add labels and title
scatter_plot.set_xlabel('Price Range')
scatter_plot.set_ylabel('Front Camera Megapixels')
scatter_plot.set_title('Front Camera Megapixels vs. Price Range')

# Show the plot
plt.grid(True)
plt.show()

# %%
train_df.plot(x='price_range',y='battery_power',kind='scatter')
plt.show()

# %%
import matplotlib.pyplot as plt

# Create the scatter plot
scatter_plot = train_df.plot(x='price_range', y='battery_power', kind='scatter', figsize=(10, 6), alpha=0.6, s=50, c='green')

# Add labels and title
scatter_plot.set_xlabel('Price Range')
scatter_plot.set_ylabel('Battery Power')
scatter_plot.set_title('Battery Power vs. Price Range')

# Show the plot
plt.grid(True)
plt.show()

# %%
counts= train_df['blue'].value_counts()
print(counts)
sns.countplot(x="blue",data = train_df)
# Out:
# 0    1010
# 1     990
# Name: blue, dtype: int64
# <AxesSubplot:xlabel='blue', ylabel='count'>

# %%
# Display the counts
counts = train_df['clock_speed'].value_counts()

# Plot the counts using seaborn's barplot
plt.figure(figsize=(12, 6))
sns.barplot(x=counts.index, y=counts, palette="viridis")
plt.xlabel('Clock Speed')
plt.ylabel('Count')
plt.title('Count of Each Clock Speed Value')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability if needed

# Annotate each bar with its count
for i, count in enumerate(counts):
    plt.text(i, count + 1, str(count), ha='center', va='bottom', fontsize=8)

plt.show()

# %% [markdown]
# ### Scaling down the data

# %%
X =  train_df.drop('price_range',axis=1)
X
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()
X_std=std.fit_transform(X)
test_df_std=std.transform(test_df)

# %%
X_std=std.fit_transform(X)
test_df_std=std.transform(test_df)

# %%
X_std
# Out:
# array([[-0.90259726, -0.9900495 ,  0.83077942, ..., -1.78686097,
#         -1.00601811,  0.98609664],
#        [-0.49513857,  1.0100505 , -1.2530642 , ...,  0.55964063,
#          0.99401789, -1.01409939],
#        [-1.5376865 ,  1.0100505 , -1.2530642 , ...,  0.55964063,
#          0.99401789, -1.01409939],
#        ...,
#        [ 1.53077336, -0.9900495 , -0.76274805, ...,  0.55964063,
#          0.99401789, -1.01409939],
#        [ 0.62252745, -0.9900495 , -0.76274805, ...,  0.55964063,
#          0.99401789,  0.98609664],
#        [-1.65833069,  1.0100505 ,  0.58562134, ...,  0.55964063,
#          0.99401789,  0.98609664]])

# %%
Y= train_df['price_range']
Y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
test_df_std
# Out:
# array([[-0.44505984,  1.0100505 ,  0.34046327, ..., -1.78686097,
#          0.99401789, -1.01409939],
#        [-0.90487356,  1.0100505 , -1.2530642 , ...,  0.55964063,
#         -1.00601811, -1.01409939],
#        [ 1.29403758,  1.0100505 ,  1.56625363, ..., -1.78686097,
#          0.99401789,  0.98609664],
#        ...,
#        [-0.12182446, -0.9900495 , -0.14985287, ...,  0.55964063,
#         -1.00601811, -1.01409939],
#        [ 0.67032987,  1.0100505 , -1.2530642 , ..., -1.78686097,
#          0.99401789, -1.01409939],
#        [ 0.07166151,  1.0100505 , -1.2530642 , ...,  0.55964063,
#         -1.00601811,  0.98609664]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 816             805     1          0.7         0   0       0          64
# 790             911     1          2.9         0   0       0          46
# 361             899     0          0.5         1  13       1          57
# 592            1263     0          0.5         0  12       0          64
# ...             ...   ...          ...       ...  ..     ...         ...
# 1791           1203     1          0.5         1   0       1          11
# 1096           1154     0          2.0         0   6       1          35
# 1932            718     1          1.6         1   1       1          30
# 235            1523     1          1.8         0   6       1          11
# 1061           1522     1          0.7         1   4       0          28
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
Y_train
# Out:
# 0       1
# 816     0
# 790     0
# 361     0
# 592     1
#        ..
# 1791    0
# 1096    3
# 1932    1
# 235     0
# 1061    1
# Name: price_range, Length: 1600, dtype: int64

# %%
X_test
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 674            1034     0          2.6         1   2       1          45
# 1699           1002     1          1.8         0   1       0          45
# 1282            609     1          0.5         0   4       1          10
# 1315           1510     0          0.6         1   1       0          32
# 1210            805     1          1.7         1   0       1          58
# ...             ...   ...          ...       ...  ..     ...         ...
# 400            1266     0          1.9         1   0       1           7
# 763            1741     1          1.8         0   0       0          14
# 385            1880     1          1.8         0   4       1          18
# 1667           1967     0          0.5         0   0       1          46
# 1820            665     1          0.7         0   0       1          31
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
Y_test
# Out:
# 674     0
# 1699    0
# 1282    1
# 1315    1
# 1210    2
#        ..
# 400     2
# 763     3
# 385     3
# 1667    1
# 1820    0
# Name: price_range, Length: 400, dtype: int64

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
df=DecisionTreeClassifier()

# %%
df.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred=df.predict(X_test)

# %%
Y_pred
# Out:
# array([0, 0, 1, 0, 3, 2, 1, 1, 1, 3, 0, 3, 1, 1, 3, 0, 0, 1, 1, 2, 3, 3,
#        1, 2, 3, 2, 1, 3, 2, 2, 2, 1, 3, 0, 3, 3, 0, 0, 1, 0, 1, 0, 2, 1,
#        0, 1, 2, 2, 1, 2, 1, 3, 1, 3, 1, 3, 1, 3, 3, 1, 0, 2, 1, 3, 2, 1,
#        0, 2, 3, 2, 1, 1, 0, 3, 3, 1, 2, 0, 1, 0, 0, 3, 1, 2, 3, 2, 3, 1,
#        1, 1, 2, 0, 1, 1, 2, 2, 3, 0, 3, 3, 3, 3, 0, 1, 2, 0, 0, 1, 0, 2,
#        0, 3, 0, 1, 2, 2, 3, 1, 1, 2, 2, 0, 0, 0, 3, 0, 1, 1, 1, 1, 0, 2,
#        0, 3, 3, 0, 3, 2, 1, 1, 0, 0, 3, 1, 0, 2, 0, 1, 0, 1, 3, 3, 1, 1,
#        0, 1, 1, 1, 3, 1, 3, 1, 3, 1, 3, 1, 2, 1, 3, 2, 2, 0, 2, 2, 0, 3,
#        3, 0, 1, 3, 0, 3, 1, 0, 2, 3, 3, 1, 2, 1, 2, 2, 1, 3, 0, 1, 1, 3,
#        3, 1, 3, 2, 0, 1, 2, 2, 2, 1, 0, 2, 0, 2, 1, 0, 2, 0, 1, 0, 3, 1,
#        0, 1, 2, 1, 3, 3, 1, 3, 2, 1, 1, 2, 3, 3, 2, 1, 0, 1, 2, 2, 3, 2,
#        1, 1, 0, 1, 2, 0, 3, 3, 3, 1, 2, 1, 0, 2, 1, 3, 2, 0, 3, 1, 1, 1,
#        2, 1, 2, 0, 3, 1, 2, 0, 0, 1, 2, 3, 0, 1, 1, 3, 3, 2, 1, 2, 2, 0,
# ...

# %%
Y_test
# Out:
# 674     0
# 1699    0
# 1282    1
# 1315    1
# 1210    2
#        ..
# 400     2
# 763     3
# 385     3
# 1667    1
# 1820    0
# Name: price_range, Length: 400, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
dt_ac=accuracy_score(Y_test,Y_pred)
dt_ac
# Out:
# 0.8325

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
X_train_std=std.fit_transform(X_train)
X_test_std=std.transform(X_test)

# %%
X_test_std
# Out:
# array([[-0.49109398, -0.99128795,  1.33165174, ...,  0.56965192,
#         -1.02020406, -1.01384584],
#        [-0.56454768,  1.00878862,  0.35176429, ...,  0.56965192,
#          0.98019606, -1.01384584],
#        [-1.46665102,  1.00878862, -1.24055283, ...,  0.56965192,
#          0.98019606,  0.98634324],
#        ...,
#        [ 1.45083838,  1.00878862,  0.35176429, ...,  0.56965192,
#         -1.02020406, -1.01384584],
#        [ 1.65054065, -0.99128795, -1.24055283, ...,  0.56965192,
#          0.98019606, -1.01384584],
#        [-1.33810703,  1.00878862, -0.99558096, ...,  0.56965192,
#         -1.02020406, -1.01384584]])

# %%
lr.fit(X_train_std,Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred=lr.predict(X_test_std)

# %%
Y_pred
# Out:
# array([0, 0, 1, 1, 2, 2, 0, 2, 2, 3, 0, 3, 1, 1, 3, 0, 0, 1, 1, 1, 3, 3,
#        1, 2, 3, 2, 2, 3, 2, 2, 2, 1, 2, 0, 3, 3, 0, 0, 0, 0, 2, 1, 2, 1,
#        0, 1, 2, 2, 1, 2, 1, 3, 1, 3, 1, 3, 1, 3, 3, 1, 0, 2, 0, 3, 2, 1,
#        1, 2, 3, 2, 1, 2, 0, 3, 3, 1, 2, 1, 0, 0, 0, 3, 1, 2, 3, 2, 2, 0,
#        1, 1, 3, 0, 1, 1, 2, 3, 3, 0, 3, 3, 3, 3, 0, 1, 2, 0, 0, 1, 0, 2,
#        0, 3, 1, 1, 2, 2, 3, 1, 2, 1, 2, 0, 0, 0, 3, 0, 1, 1, 0, 1, 0, 2,
#        0, 3, 3, 0, 3, 2, 2, 1, 0, 0, 3, 1, 0, 2, 0, 0, 0, 1, 3, 3, 1, 1,
#        0, 2, 1, 0, 3, 1, 3, 1, 2, 2, 3, 1, 2, 2, 3, 2, 2, 0, 2, 2, 0, 3,
#        3, 0, 0, 3, 0, 3, 0, 0, 2, 3, 3, 1, 2, 1, 2, 3, 2, 2, 0, 1, 1, 3,
#        3, 1, 3, 2, 0, 1, 2, 2, 2, 1, 0, 2, 0, 3, 2, 0, 2, 0, 1, 0, 2, 1,
#        0, 1, 2, 1, 3, 3, 0, 3, 2, 1, 0, 2, 3, 3, 2, 1, 0, 1, 3, 2, 3, 2,
#        2, 1, 0, 1, 3, 0, 3, 3, 3, 1, 2, 1, 0, 1, 1, 3, 2, 0, 3, 1, 1, 1,
#        2, 1, 2, 0, 3, 2, 2, 0, 0, 1, 3, 3, 0, 1, 1, 2, 3, 2, 2, 2, 2, 0,
# ...

# %%
from sklearn.metrics import accuracy_score

# Assuming Y_test and Y_pred are defined elsewhere in your code
lr_ac = accuracy_score(Y_test, Y_pred)

# %%
lr_ac
# Out:
# 0.96

# %% [markdown]
# ## KNN (K-nearest-neighbours)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train_std,Y_train)
# Out:
# KNeighborsClassifier()

# %%
Y_pred=knn.predict(X_test_std)

# %%
Y_pred
# Out:
# array([0, 1, 1, 0, 1, 1, 0, 2, 1, 3, 0, 3, 2, 0, 2, 0, 1, 1, 1, 2, 3, 2,
#        1, 3, 3, 2, 2, 1, 1, 3, 1, 1, 2, 0, 3, 1, 0, 0, 1, 1, 0, 1, 2, 0,
#        0, 2, 1, 2, 0, 2, 1, 1, 0, 2, 2, 2, 0, 2, 2, 0, 0, 0, 0, 2, 0, 2,
#        0, 2, 2, 2, 1, 1, 0, 3, 3, 1, 3, 0, 1, 0, 0, 3, 2, 2, 3, 1, 2, 0,
#        2, 0, 1, 0, 0, 1, 2, 2, 2, 0, 1, 1, 1, 3, 0, 0, 2, 0, 0, 1, 1, 0,
#        0, 3, 2, 2, 2, 0, 1, 0, 1, 1, 1, 0, 0, 0, 3, 1, 1, 0, 1, 1, 0, 2,
#        0, 2, 2, 1, 2, 2, 2, 2, 0, 1, 3, 0, 1, 2, 0, 1, 0, 0, 2, 3, 1, 0,
#        0, 0, 1, 0, 1, 2, 2, 0, 2, 2, 3, 0, 3, 2, 3, 2, 1, 0, 1, 0, 1, 3,
#        2, 0, 1, 3, 0, 3, 0, 2, 1, 3, 3, 1, 1, 1, 2, 1, 2, 2, 0, 2, 1, 3,
#        2, 0, 3, 2, 0, 3, 2, 1, 2, 0, 0, 2, 1, 2, 2, 0, 3, 0, 1, 0, 1, 1,
#        2, 2, 2, 2, 2, 1, 0, 3, 2, 1, 0, 1, 3, 3, 1, 1, 0, 1, 2, 0, 1, 2,
#        1, 0, 0, 2, 1, 0, 3, 2, 2, 0, 0, 1, 1, 3, 1, 2, 1, 0, 1, 0, 1, 2,
#        2, 2, 2, 0, 1, 0, 3, 0, 0, 2, 2, 3, 0, 2, 1, 2, 3, 1, 1, 0, 2, 1,
# ...

# %%
Y_test
# Out:
# 674     0
# 1699    0
# 1282    1
# 1315    1
# 1210    2
#        ..
# 400     2
# 763     3
# 385     3
# 1667    1
# 1820    0
# Name: price_range, Length: 400, dtype: int64

# %%
knn_ac=accuracy_score(Y_test,Y_pred)

# %%
knn_ac
# Out:
# 0.5225

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Assuming X_train, X_test, Y_train, Y_test are defined elsewhere in your code
# Standardize features
std = StandardScaler()
X_train_std = std.fit_transform(X_train)
X_test_std = std.transform(X_test)

# Initialize KNN classifier
knn = KNeighborsClassifier()

# Train the classifier
knn.fit(X_train_std, Y_train)

# Predict on the test set
Y_pred = knn.predict(X_test_std)

# Calculate accuracy
knn_ac = accuracy_score(Y_test, Y_pred)
knn_ac
# Out:
# 0.5225

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Create a Random Forest Regression model
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the Random Forest Regression model
rf_regressor.fit(X_train_std, Y_train)

# Predict on the test set
Y_pred_rf = rf_regressor.predict(X_test_std)

# Evaluate the Random Forest Regression model
mse_rf = mean_squared_error(Y_test, Y_pred_rf)
print("Mean Squared Error (Random Forest):", mse_rf)
# Out:
# Mean Squared Error (Random Forest): 0.07599399999999999

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Mean Absolute Error (MAE)
mae_rf = mean_absolute_error(Y_test, Y_pred_rf)
print("Mean Absolute Error (Random Forest):", mae_rf)

# Root Mean Squared Error (RMSE)
rmse_rf = mean_squared_error(Y_test, Y_pred_rf, squared=False)
print("Root Mean Squared Error (Random Forest):", rmse_rf)

# R-squared (R2) score
r2_rf = r2_score(Y_test, Y_pred_rf)
print("R-squared (Random Forest):", r2_rf)
# Out:
# Mean Absolute Error (Random Forest): 0.17655
# Root Mean Squared Error (Random Forest): 0.27567009268326514
# R-squared (Random Forest): 0.938504986749206
# C:\Users\rajsi\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Create a Random Forest Regression model
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the Random Forest Regression model
rf_regressor.fit(X_train_std, Y_train)

# Predict on the test set
Y_pred_rf = rf_regressor.predict(X_test_std)

# Evaluate the Random Forest Regression model
mse_rf = mean_squared_error(Y_test, Y_pred_rf)
print("Mean Squared Error (Random Forest):", mse_rf)
# Out:
# Mean Squared Error (Random Forest): 0.07599399999999999

# %% [markdown]
# # Checking Accuracy of the models

# %%
from sklearn.metrics import mean_squared_error

# Assuming Y_test contains the true labels for the test set
# Y_pred_rf contains the predicted labels by the Random Forest model

# Calculate Mean Squared Error (MSE) as a measure of accuracy
rf_mse = mean_squared_error(Y_test, Y_pred_rf)

# Assuming you want to convert MSE to an accuracy score (lower MSE is better)
# You may want to do some transformation or normalization depending on your problem
# For example, you can define accuracy as 1 - MSE
rf_ac = 1 - rf_mse

# Now, you can include rf_ac in the list of accuracy scores
accuracy_scores = [dt_ac, knn_ac, lr_ac, rf_ac]
accuracy_scores
# Out:
# [0.8325, 0.5225, 0.96, 0.924006]

# %%
import matplotlib.pyplot as plt

# Define the algorithms and their corresponding accuracy scores
algorithms = ['Decision Tree', 'KNN', 'Logistic Regression', 'Random Forest']
accuracy_scores = [dt_ac, knn_ac, lr_ac, rf_ac]  # Include rf_ac for Random Forest

# Create a bar plot
plt.figure(figsize=(10, 6))  # Set the figure size for better visualization
plt.bar(algorithms, accuracy_scores, color=['skyblue', 'lightgreen', 'salmon', 'orange'])  # Add color for Random Forest

# Add labels and title
plt.xlabel('Algorithms', fontsize=14)  # Set the x-label with a larger font size
plt.ylabel('Accuracy Score', fontsize=14)  # Set the y-label with a larger font size
plt.title('Comparison of Algorithm Accuracy Scores', fontsize=16)  # Add a title to the plot

# Add value labels on top of each bar
for i, score in enumerate(accuracy_scores):
    plt.text(i, score + 0.005, f'{score:.2f}', ha='center', fontsize=12)

# Show the plot
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add a horizontal grid for better readability
plt.ylim(0, 1)  # Set y-axis limit from 0 to 1
plt.xticks(fontsize=12, rotation=45)  # Rotate x-axis labels for better readability
plt.yticks(fontsize=12)  # Set font size for y-axis labels

plt.show()

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Assuming X_train_std, X_test_std, Y_train are defined elsewhere in your code

# Instantiate SVM classifier
svm = SVC(kernel='linear')  # You can choose different kernels like 'rbf', 'poly', etc.

# Fit the classifier to the training data
svm.fit(X_train_std, Y_train)

# Predict on the test set
Y_pred_svm = svm.predict(X_test_std)

# Calculate accuracy
svm_ac = accuracy_score(Y_test, Y_pred_svm)
print("Accuracy of SVM:", svm_ac)
# Out:
# Accuracy of SVM: 0.9575

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# Assuming X_train_std, X_test_std, Y_train are defined elsewhere in your code

# Instantiate GBM classifier
gbm = GradientBoostingClassifier()

# Fit the classifier to the training data
gbm.fit(X_train_std, Y_train)

# Predict on the test set
Y_pred_gbm = gbm.predict(X_test_std)

# Calculate accuracy
gbm_ac = accuracy_score(Y_test, Y_pred_gbm)
print("Accuracy of GBM:", gbm_ac)
# Out:
# Accuracy of GBM: 0.8825

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# Assuming X_train_std, X_test_std, Y_train are defined elsewhere in your code

# Instantiate Neural Network classifier
nn = MLPClassifier(hidden_layer_sizes=(500, ), activation='relu', solver='adam', max_iter=500)

# Fit the classifier to the training data
nn.fit(X_train_std, Y_train)

# Predict on the test set
Y_pred_nn = nn.predict(X_test_std)

# Calculate accuracy
nn_ac = accuracy_score(Y_test, Y_pred_nn)
print("Accuracy of Neural Network:", nn_ac)
# Out:
# Accuracy of Neural Network: 0.9175

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# Assuming X_train_std, X_test_std, Y_train are defined elsewhere in your code

# Instantiate Naive Bayes classifier
nb = GaussianNB()

# Fit the classifier to the training data
nb.fit(X_train_std, Y_train)

# Predict on the test set
Y_pred_nb = nb.predict(X_test_std)

# Calculate accuracy
nb_ac = accuracy_score(Y_test, Y_pred_nb)
print("Accuracy of Naive Bayes:", nb_ac)
# Out:
# Accuracy of Naive Bayes: 0.7575

# %%
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.metrics import accuracy_score

# Assuming X_train_std, X_test_std, Y_train are defined elsewhere in your code

# Instantiate Gaussian Process classifier with RBF kernel
kernel = 1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-1, 1e3))  # Adjust the upper bound as needed
gpc = GaussianProcessClassifier(kernel=kernel, random_state=0)

# Fit the classifier to the training data
gpc.fit(X_train_std, Y_train)

# Predict on the test set
Y_pred_gpc = gpc.predict(X_test_std)

# Calculate accuracy
gpc_ac = accuracy_score(Y_test, Y_pred_gpc)
print("Accuracy of Gaussian Process Classifier:", gpc_ac)
# Out:
# C:\Users\rajsi\AppData\Roaming\Python\Python39\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# C:\Users\rajsi\AppData\Roaming\Python\Python39\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# C:\Users\rajsi\AppData\Roaming\Python\Python39\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ...

# %%
pip install xgboost
# Out:
# ...
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\rajsi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\rajsi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\rajsi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\rajsi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\rajsi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\rajsi\anaconda3\lib\site-packages)
# ...

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score

# Assuming X_train_std, X_test_std, Y_train are defined elsewhere in your code

# Convert data to DMatrix format (optimized for XGBoost)
dtrain = xgb.DMatrix(X_train_std, label=Y_train)
dtest = xgb.DMatrix(X_test_std)

# Set XGBoost parameters
param = {
    'max_depth': 6,  # Maximum depth of the tree
    'eta': 0.3,  # Learning rate
    'objective': 'multi:softmax',  # Objective function for multi-class classification
    'num_class': len(set(Y_train))  # Number of classes
}

# Train the model
num_round = 100  # Number of boosting rounds
xgb_model = xgb.train(param, dtrain, num_round)

# Make predictions
Y_pred_xgb = xgb_model.predict(dtest)

# Convert predictions to integers
Y_pred_xgb = Y_pred_xgb.astype(int)

# Calculate accuracy
xgb_ac = accuracy_score(Y_test, Y_pred_xgb)
print("Accuracy of XGBoost Classifier:", xgb_ac)
# Out:
# Accuracy of XGBoost Classifier: 0.8975

# %%
import lightgbm as lgb
from sklearn.metrics import accuracy_score

# Assuming X_train_std, X_test_std, Y_train are defined elsewhere in your code

# Convert data to lightgbm Dataset format
train_data = lgb.Dataset(X_train_std, label=Y_train)
test_data = lgb.Dataset(X_test_std, label=Y_test)

# Set parameters for LightGBM
params = {
    'objective': 'multiclass',  # Specify the task as multiclass classification
    'num_class': len(set(Y_train)),  # Number of classes in the target variable
    'metric': 'multi_logloss',  # Evaluation metric
    'verbosity': -1,  # Set verbosity to -1 to suppress messages
}

# Train the model
num_round = 100  # Number of boosting rounds
lgb_model = lgb.train(params, train_data, num_round)

# Make predictions on the test set
Y_pred_lgb = lgb_model.predict(X_test_std)

# Convert predicted probabilities to class labels
Y_pred_lgb_class = [np.argmax(pred) for pred in Y_pred_lgb]

# Calculate accuracy
lgb_ac = accuracy_score(Y_test, Y_pred_lgb_class)
print("Accuracy of LightGBM Classifier:", lgb_ac)
# Out:
# Accuracy of LightGBM Classifier: 0.8775

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import accuracy_score

# Assuming X_train_std, X_test_std, Y_train are defined elsewhere in your code

# Instantiate Extra Trees classifier
extra_trees = ExtraTreesClassifier(n_estimators=1000, random_state=6)

# Fit the classifier to the training data
extra_trees.fit(X_train_std, Y_train)

# Predict on the test set
Y_pred_extra_trees = extra_trees.predict(X_test_std)

# Calculate accuracy
extra_trees_ac = accuracy_score(Y_test, Y_pred_extra_trees)
print("Accuracy of Extra Trees Classifier:", extra_trees_ac)
# Out:
# Accuracy of Extra Trees Classifier: 0.8425

# %%
import matplotlib.pyplot as plt

# Define the classifiers and their corresponding accuracy scores
classifiers = ['Decision Tree', 'KNN', 'Logistic Regression', 'Random Forest', 'SVM', 'GBM', 'NN', 'Naive Bayes', 'Gaussian Process', 'XGBoost', 'LightGBM', 'Extra Trees']
accuracies = [dt_ac, knn_ac, lr_ac, rf_ac, svm_ac, gbm_ac, nn_ac, nb_ac, gpc_ac, xgb_ac, lgb_ac, extra_trees_ac]

# Define colors for each classifier
colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan', 'magenta', 'lime']

# Plot the accuracy scores with different colors
plt.figure(figsize=(12, 8))
bars = plt.barh(classifiers, accuracies, color=colors)
plt.xlabel('Accuracy')
plt.title('Accuracy of Different Classifiers')
plt.xlim(0, 1)  # Set x-axis limit from 0 to 1
plt.gca().invert_yaxis()  # Invert y-axis to have the highest accuracy at the top

# Add labels to the bars
for bar, acc in zip(bars, accuracies):
    plt.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, round(acc, 2), 
             va='center', ha='left', fontsize=8, color='black')

plt.show()
